# %%
# 🧪 UPDATED SMOKE TEST (For 'paquets' folder)
import pandas as pd
import os

# 1. Check path (Using 'paquets' now)
file_path = 'parquets/data_time.parquet' # Change name for your role
if os.path.exists(file_path):
    print("✅ File Found!")
else:
    print(f"❌ ERROR: Could not find file at {file_path}")

# 2. Try to load
try:
    df = pd.read_parquet(file_path, engine='pyarrow')
    print(f"✅ Loaded {df.shape[0]} rows from 'paquets'.")
except Exception as e:
    print(f"❌ Load Failed: {e}")
# Out:
# ✅ File Found!
# ❌ Load Failed: Repetition level histogram size mismatch
